# %%
from evaluation import *

# %%
filename = 'filtered_3way_after.xes'
# filename = 'filtered_3way_after_80%.xes'
# filename = 'PrepaidTravelCost (copy).xes'

# %%
# log, VARIANT = read_xes(filename, n_DPI = 15)
log, VARIANT = read_xes(filename)
# Out:
# ...
# =READ THE XES FILElength of log 3170
# length of event 33295
# number of variants : 481

# %%
from pm4py.algo.discovery.footprints import algorithm as footprints_discovery

fp_log = footprints_discovery.apply(log, variant=footprints_discovery.Variants.ENTIRE_EVENT_LOG)

# %%
activities = list(fp_log['activities'])

# %%
def simplify_event_name(log, activities, inverse=False ) : 
    import string
    A=string.ascii_uppercase[:len(activities)]
    for l in log : 
        for a in l : 
            if inverse : 
                a['concept:name'] = activities[A.index(a['concept:name'])]
            else : 
                a['concept:name'] = A[activities.index(a['concept:name'])]
    return A, log

# %%
A, log = simplify_event_name(log, activities)

# %%
for i,v in enumerate(VARIANT) : 
    variant =''
    for a in v.split(',') : 
        variant += A[activities.index(a)] + ','
    VARIANT[i] = variant[:-1]

# %%
from evaluation import *
import time
from pm4py.algo.discovery.inductive import algorithm as inductive_miner
from pm4py.algo.discovery.heuristics import algorithm as heuristic_miner

# %%
net, im, fm = inductive_miner.apply(log)
# net, im, fm = heuristic_miner.apply(log)

# %%
gviz = pn_visualizer.apply(net, im, fm)
pn_visualizer.view(gviz)

# %%
from pm4py.statistics.traces.log import case_statistics
variants_count = case_statistics.get_variant_statistics(log)
variants_count = sorted(variants_count, key=lambda x: x['count'], reverse=True)

import pandas as pd

stat=[]
d=[]
for v in variants_count : 
    stat.append([len(v['variant'].split(',')), v['count']])
    data=pd.DataFrame(stat, columns = ['len','size'])
    d.append(v['count'])
d=np.array(d)

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(num=None, figsize=(40, 40), dpi=80, facecolor='w', edgecolor='k')
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.bar(VARIANT, d/sum(d))
plt.xticks(rotation=90)

# %%
w = 0.25
tf = 1
nb_clus = 4
mcs = 0.25
N = 1 
visual=True
output=True
p=1

# %%
total_clustering(log=log, VARIANT=VARIANT, k=nb_clus, output=output, visual=visual,w=w,  tf=tf, mcs=mcs,N=N,p=p)
result = total_evaluation()
visualize_evaluation(result)
# Out:
# * active clustering started, it may take some time to finish. to see the progress, please use output = True
# ****************************************************************************************************
# START OF No. 0 CLUSTERING
#
#
# Clustering() is called. mcs:(0.25,), tf:1, w:0.25
# ----------------------------------------------------------------------------------------------------
# START OF LOOP with cur_dpi
# ...
# W creater called with w : 0.25 and target size 792.5
#
# 		P,A,C,K,T___added with size 1106 // 1106 out of 792.5  // total size : 3170
# W creater END with its size: 1
# ...
#
#  * C is empty set - size of |C|:0 ->  R[0] or  is to be added.
#
# 	cur_dpi = R[0] P,A,C,K,T...
#
#
#
#  * Fitness check to be done with cur_dpi
# 	 P,A,C,K,T...
#
#  * size of C is 0, fitness check is skipped and cur_dpi is added to C
#
#  * CASE of fit 1 >= 1 tf -> Cur_dpi is added to cluster C & removed from R
# ...

# %%
CS = A_clustering(
    log, VARIANT,
    w = 0.25,  tf = 1, nb_clus = 4, mcs = 0.25,
    N = 1,  
    visual=False,
    output=False
    
)

# %%
visualization_total(log, VARIANT, CS, freq_check=True)

# %%
quality_measure(log,CS)

# %%
evaluation_w_hm(log)
