# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from evaluation import *
import time

# %%
filename='./xes/DomesticDeclarations.xes'

# %%
log, VARIANT = read_xes(filename)
# Out:
# HBox(children=(IntProgress(value=0, description='parsing log, completed traces :: ', max=10500, style=Progress…
# ====================================================================================================
# =READ THE XES FILE
# length of log 10500
# length of event 56437
# number of variants : 99

# %%
d = dpi_distribution(log)

# %%
distribution_plot(d, filename)
# Out:
# array([4.618e+03, 2.473e+03, 1.392e+03, 5.750e+02, 3.450e+02, 1.880e+02,
#        1.740e+02, 1.340e+02, 7.700e+01, 5.700e+01, 4.900e+01, 4.000e+01,
#        3.600e+01, 3.100e+01, 2.900e+01, 2.200e+01, 2.100e+01, 2.000e+01,
#        1.800e+01, 1.400e+01, 1.100e+01, 1.000e+01, 8.000e+00, 8.000e+00,
#        8.000e+00, 7.000e+00, 6.000e+00, 6.000e+00, 6.000e+00, 5.000e+00,
#        5.000e+00, 4.000e+00, 4.000e+00, 4.000e+00, 4.000e+00, 4.000e+00,
#        3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00,
#        3.000e+00, 2.000e+00, 2.000e+00, 2.000e+00, 2.000e+00, 2.000e+00,
#        2.000e+00, 2.000e+00, 2.000e+00, 2.000e+00, 2.000e+00, 1.000e+00,
#        1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#        1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#        1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#        1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#        1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#        1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#        1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#        1.000e+00, 1.000e+00, 1.000e+00])

# %%
distribution_fitting(d,filename)

# %%
from scipy.stats import norm, kurtosis, skew
kurtosis(d)
skew(d)
# Out:
# 50.47914689052968
# 6.898852024205939

# %%
pickle_name = './pickles/result_' + filename[6:-4] + '_2020-12-22.p'

# %%
result=pickle.load(open(pickle_name, 'rb'))

# %%
visualize_evaluation(result, pickle_name[17:-13])

# %%
np.round(result,3)
# Out:
# array([[0.995, 0.939, 0.962, 0.918],
#        [0.969, 0.893, 0.756, 0.668],
#        [0.929, 0.961, 0.716, 0.596],
#        [0.997, 0.892, 0.816, 0.698]])

# %%
runtime = pickle.load(open('./pickles/runtime_DomesticDeclarations_2020-12-22.p', 'rb'))

# %%
np.round(runtime,3)
# Out:
# array([15.7  ,  0.043,  0.02 ,  0.026])

# %%
sum(d>np.average(d))/len(d)
# Out:
# 0.08080808080808081

# %%
from scipy.stats import norm, kurtosis, skew
kurtosis(d)
skew(d)
# Out:
# 50.47914689052968
# 6.898852024205939

# %%
len(d)
np.median(d)
np.average(d)
np.max(d)
np.min(d)
np.quantile(d, q=[0.25,0.5,0.75])
np.sqrt(np.var(d))
sum(d)
sum(d[d>1])
sum(d==1)
sum(d==1) / sum(d)
# Out:
# 99
# 2.0
# 106.06060606060606
# 4618.0
# 1.0
# array([1. , 2. , 7.5])
# 539.5272681659214
# 10500.0
# 10454.0
# 46
# 0.004380952380952381
