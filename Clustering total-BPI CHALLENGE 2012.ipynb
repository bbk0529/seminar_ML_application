# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from evaluation import *
import time

# %%
filename='./xes/BPI_Challenge_2012.xes'

# %%
log, VARIANT = read_xes(filename)
# Out:
# HBox(children=(IntProgress(value=0, description='parsing log, completed traces :: ', max=13087, style=Progress…
# ====================================================================================================
# =READ THE XES FILE
# length of log 13087
# length of event 262200
# number of variants : 4366

# %%
d = dpi_distribution(log)

# %%
distribution_plot(d, filename)
# Out:
# array([3.429e+03, 1.872e+03, 2.710e+02, ..., 1.000e+00, 1.000e+00,
#        1.000e+00])

# %%
distribution_fitting(d,filename)

# %%
from scipy.stats import norm, kurtosis, skew
kurtosis(d)
skew(d)
# Out:
# 2734.691439171705
# 50.82236374008843

# %%
len(d)
np.average(d)
np.quantile(d, q=[0.25,0.5,0.75])
np.sqrt(np.var(d))
sum(d==1)
sum(d==1) / sum(d)
# Out:
# 4366
# 2.9974805313788364
# array([1., 1., 1.])
# 59.51696111718352
# 3754
# 0.2868495453503477

# %%
pickle_name = './pickles/result_' + filename[6:-4] + '_2020-12-22.p'

# %%
result=pickle.load(open(pickle_name, 'rb'))

# %%
visualize_evaluation(result, pickle_name[17:-13])

# %%
np.round(result,3)
# Out:
# array([[0.99 , 0.538, 0.939, 0.7  ],
#        [0.968, 0.564, 0.914, 0.564],
#        [0.974, 0.364, 0.875, 0.554],
#        [0.974, 0.49 , 0.916, 0.577]])

# %%
runtime = pickle.load(open('./pickles/runtime_BPI_Challenge_2012_2020-12-22.p', 'rb'))

# %%
runtime
# Out:
# [2282.1140892505646, 0.2783515453338623, 15.762970209121704, 0.995417594909668]

# %%
pickle_name = './pickles/CS_act_BPI_Challenge_2012_2020-12-22.p'

# %%
CS_act=pickle.load(open(pickle_name, 'rb'))

# %%
visualization_total(log, VARIANT, CS_act, freq_check=True)
# Out:
# visualization of VARIANT
# #variants:4366 / #traces:13087 / fitness0.9767274991718963
# visualization of each cluster in CS
# #variants:1 / #traces:3429 / fitness1.0
# #variants:3 / #traces:2352 / fitness1.0
# #variants:35 / #traces:1499 / fitness1.0
# #variants:4327 / #traces:5807 / fitness0.9766884527059169

# %%
total_evaluation
