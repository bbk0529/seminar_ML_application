# %%
import clustering_util
import importlib
from clustering_util import *
importlib.reload(clustering_util)
# Out:
# <module 'clustering_util' from '/home/bk/dev/seminar/clustering_util.py'>

# %%
# filename = 'filtered_3way_after_80%.xes'
filename = 'PrepaidTravelCost.xes'
log, VARIANT = read_xes(filename,1)
# Out:
# HBox(children=(IntProgress(value=0, description='parsing log, completed traces :: ', max=2099, style=ProgressS…
# length of trace 2099
# length of event 18246
# number of variants : 202

# %%
CS=CS_creator(VARIANT, type='boa', k=20)
# Out:
# boa

# %%
import pickle
pickle.dump(CS, open( "boa_clustering.p", "wb" ) )

# %%
visualization_total(log, VARIANT, CS, freq_check=True)
# Out:
# visualization of VARIANT
# #variants:202 / #traces:2099 / fitness0.9016378715864678
# visualization of each cluster in CS
# #variants:12 / #traces:201 / fitness0.9323797139141743
# #variants:17 / #traces:675 / fitness0.9868573438842352
# #variants:8 / #traces:25 / fitness0.8980675133322338
# #variants:7 / #traces:32 / fitness0.9832448936712369
# #variants:8 / #traces:9 / fitness0.9489795918367347
# #variants:20 / #traces:67 / fitness0.9036662600418424
# #variants:16 / #traces:122 / fitness0.9946873722926032
# #variants:13 / #traces:41 / fitness0.9717741935483871
# #variants:10 / #traces:17 / fitness0.9775829266275127
# #variants:13 / #traces:136 / fitness0.9874856076142472
# #variants:15 / #traces:372 / fitness0.9951129086619481
# #variants:5 / #traces:19 / fitness0.9640287769784173
# #variants:6 / #traces:16 / fitness0.8721674298461899
# #variants:12 / #traces:34 / fitness0.9106463878326996
# #variants:12 / #traces:147 / fitness0.9932432432432432
# #variants:3 / #traces:4 / fitness1.0
# #variants:4 / #traces:7 / fitness0.9841269841269842
# #variants:6 / #traces:18 / fitness0.985689193710271
# #variants:5 / #traces:85 / fitness0.9989506820566632
# #variants:10 / #traces:72 / fitness0.951135502809166
